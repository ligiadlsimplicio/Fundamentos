# %%
import pandas as pd

df = pd.read_parquet("teste.parquet")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   nome    3 non-null      str
# dtypes: int64(1), str(1)
# memory usage: 193.0 bytes

# %%
df.describe()
# Out:
#         id
# count  3.0
# mean   2.0
# std    1.0
# min    1.0
# 25%    1.5
# 50%    2.0
# 75%    2.5
# max    3.0

# %%
df.isna().sum()
# Out:
# id      0
# nome    0
# dtype: int64

# %% [markdown]
# **Análise da Estrutura (`df.info()`):**
# * A tabela possui um total de 3 registros (linhas) e 2 colunas (`id` e `nome`).
# * Todas as colunas possuem 3 valores preenchidos (não-nulos), sendo 1 coluna numérica (`int64`) e 1 textual (`str`).

# %% [markdown]
# **Análise Estatística (`df.describe()`):**
# * Apenas a coluna `id` possui dados numéricos calculáveis.
# * Foram analisados 3 registros, com valores variando entre 1 (mínimo) e 3 (máximo), resultando em uma média de 2,0.

# %% [markdown]
# **Análise de Valores Nulos (`df.isna().sum()`):**
# * Não foram encontrados valores ausentes ou nulos em nenhuma das colunas (`id` e `nome` apresentam 0 nulos).
