# %% [markdown]
# <a href="https://colab.research.google.com/github/ligiadlsimplicio/Fundamentos/blob/main/notebooks/Encontro01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pensamento Computacional
#
# - Google Colab (botebook com código)
# - Git Hub (versionamento)

# %% [markdown]
# ## Noções Gerais

# %% [markdown]
# ## Fundamentos Programação
