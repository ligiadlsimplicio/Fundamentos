# %% [markdown]
# <a href="https://colab.research.google.com/github/ligiadlsimplicio/Fundamentos/blob/main/Encontro01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pensamento Computacional
#
# - Google Colab (botebook com código)
# - Git Hub (versionamento)

# %% [markdown]
# ## Noções Gerais
#
# - Exemplos a partir de coleta de dados
#   - Site Ministério da Gestão e da Inovação em Serviços Públicos
#     - [x] Link do site: https://www.gov.br/gestao/pt-br/assuntos/noticias
#     - [x] Entender a estrutura da fonte de informação
#     - [ ] Realizar a coleta
#     - [ ] Inserir as informações em um banco de dados
#     - [ ] Utilizar as informações
# ### Padrão de paginação de noticias
#  - https://www.gov.br/gestao/pt-br/assuntos/noticias?b_start:int=0
#  - https://www.gov.br/gestao/pt-br/assuntos/noticias?b_start:int=10

# %%
# programas/bibliotecas utilizados no script/codigo
import httpx
fron bs4 import BeautifulSoup

# %% [markdown]
# ## Fundamentos Programação
